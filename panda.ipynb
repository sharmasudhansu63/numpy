# %%
import pandas as pd

# %%
import numpy as np

# %%
df = pd.read_csv("N_data.csv")
print(df)
# Out:
#       show_id     type                          title  \
# 0      s10651    Movie             Garfield Gets Real
# 1       s2042    Movie                    Sky on Fire
# 2       s8669    Movie                     Alien Xmas
# 3       s1115    Movie                       Arthur
# 4      s13903  TV Show                           GLOW
# ...       ...      ...                            ...
# 19995  s11285    Movie            Muppets Most Wanted
# 19996  s11965    Movie    R.L. Stine's Mostly Ghostly
# 19997   s5391  TV Show                          Vexed
# 19998    s861    Movie  Chhota Bheem: Bheem vs Aliens
# 19999  s15796    Movie             Lying and Stealing
#
#                             director  \
# 0      Mark A.Z. Dippé, Kyung Ho Lee
# 1                          Ringo Lam
# 2                     Stephen Chiodo
# 3                                NaN
# 4                                NaN
# ...                              ...
# 19995                            NaN
# 19996                Richard Correll
# 19997                            NaN
# 19998                  Rajiv Chilaka
# 19999                   Matt Aselton
#
#                                                     cast           country  \
# 0      Frank Welker, Wally Wingert, Gregg Berger, Jen...     United States
# 1      Daniel Wu, Joseph Chang, Amber Kuo, Zhang Jing...  China, Hong Kong
# 2      Keythe Farley, Dee Bradley Baker, Kaliayh Rham...     United States
# 3                                                    NaN     United States
# 4      Alison Brie, Betty Gilpin, Marc Maron, Britney...     United States
# ...                                                  ...               ...
# 19995  Ricky Gervais, Ty Burrell, Tina Fey, Kermit th...     United States
# 19996  Madison Pettis, Sterling Beaumon, Luke Benward...     United States
# 19997  Toby Stephens, Miranda Raison, Lucy Punch, Nic...    United Kingdom
# 19998  Vatsal Dubey, Julie Tejwani, Rupa Bhimani, Jig...               NaN
# 19999  Theo James, Emily Ratajkowski, Fred Melamed, E...     United States
#
#               date_added  release_year rating   duration
# 0        January 1, 2020        2007.0   TV-Y     78 min
# 1         August 5, 2017        2016.0  TV-MA        NaN
# 2      November 20, 2020        2020.0   TV-Y     42 min
# 3          April 1, 2019        2011.0  PG-13    110 min
# 4         August 9, 2019        2019.0    NaN  3 Seasons
# ...                  ...           ...    ...        ...
# 19995  September 1, 2020        2014.0     PG    110 min
# 19996     August 1, 2018        2008.0     PG     98 min
# 19997                NaN           NaN    NaN  2 Seasons
# 19998      July 22, 2021           NaN  TV-Y7     69 min
# 19999      June 30, 2021        2019.0    NaN        NaN
#
# [20000 rows x 10 columns]

# %%
df.head()
# Out:
#   show_id     type               title                       director  \
# 0  s10651    Movie  Garfield Gets Real  Mark A.Z. Dippé, Kyung Ho Lee
# 1   s2042    Movie         Sky on Fire                      Ringo Lam
# 2   s8669    Movie          Alien Xmas                 Stephen Chiodo
# 3   s1115    Movie            Arthur                              NaN
# 4  s13903  TV Show                GLOW                            NaN
#
#                                                 cast           country  \
# 0  Frank Welker, Wally Wingert, Gregg Berger, Jen...     United States
# 1  Daniel Wu, Joseph Chang, Amber Kuo, Zhang Jing...  China, Hong Kong
# 2  Keythe Farley, Dee Bradley Baker, Kaliayh Rham...     United States
# 3                                                NaN     United States
# 4  Alison Brie, Betty Gilpin, Marc Maron, Britney...     United States
#
#           date_added  release_year rating   duration
# 0    January 1, 2020        2007.0   TV-Y     78 min
# 1     August 5, 2017        2016.0  TV-MA        NaN
# 2  November 20, 2020        2020.0   TV-Y     42 min
# 3      April 1, 2019        2011.0  PG-13    110 min
# 4     August 9, 2019        2019.0    NaN  3 Seasons

# %%
df.tail(5)
# Out:
#       show_id     type                          title         director  \
# 19995  s11285    Movie            Muppets Most Wanted              NaN
# 19996  s11965    Movie    R.L. Stine's Mostly Ghostly  Richard Correll
# 19997   s5391  TV Show                          Vexed              NaN
# 19998    s861    Movie  Chhota Bheem: Bheem vs Aliens    Rajiv Chilaka
# 19999  s15796    Movie             Lying and Stealing     Matt Aselton
#
#                                                     cast         country  \
# 19995  Ricky Gervais, Ty Burrell, Tina Fey, Kermit th...   United States
# 19996  Madison Pettis, Sterling Beaumon, Luke Benward...   United States
# 19997  Toby Stephens, Miranda Raison, Lucy Punch, Nic...  United Kingdom
# 19998  Vatsal Dubey, Julie Tejwani, Rupa Bhimani, Jig...             NaN
# 19999  Theo James, Emily Ratajkowski, Fred Melamed, E...   United States
#
#               date_added  release_year rating   duration
# 19995  September 1, 2020        2014.0     PG    110 min
# 19996     August 1, 2018        2008.0     PG     98 min
# 19997                NaN           NaN    NaN  2 Seasons
# 19998      July 22, 2021           NaN  TV-Y7     69 min
# 19999      June 30, 2021        2019.0    NaN        NaN

# %%
df.sample(5)
# Out:
#       show_id     type                        title          director  \
# 3666   s14036  TV Show            My Only Love Song               NaN
# 3132   s12061    Movie  Kilometers and Kilometers            Jeo Baby
# 13261    s364    Movie                Machete Kills  Robert Rodriguez
# 5983    s4861    Movie                 Khido Khundi      Rohit Jugraj
# 18381   s6100    Movie                       Jinxed     Stephen Herek
#
#                                                     cast  \
# 3666   Seung-yeon Gong, Jong-hyun Lee, Yeon-seo Kim, ...
# 3132   Tovino Thomas, India Jarvis, Joju George, Sidh...
# 13261  Danny Trejo, Sofía Vergara, Charlie Sheen, Mic...
# 5983   Ranjit Bawa, Mandy Takhar, Manav Vij, Elnaaz N...
# 18381  Ciara Bravo, Jacob Bertrand, Elena Kampouris, ...
#
#                      country         date_added  release_year rating  duration
# 3666             South Korea       June 9, 2017        2017.0  TV-MA  1 Season
# 3132                   India                NaN        2020.0  TV-MA       NaN
# 13261  United States, Russia  November 22, 2020        2013.0      R   108 min
# 5983                   India    October 1, 2018        2018.0    NaN   151 min
# 18381  United States, Canada   November 2, 2019        2013.0   TV-Y    69 min

# %%
df.shape
# Out:
# (20000, 10)

# %%
df.columns
# Out:
# Index(['show_id', 'type', 'title', 'director', 'cast', 'country', 'date_added',
#        'release_year', 'rating', 'duration'],
#       dtype='object')

# %%
df.dtypes
# Out:
# show_id          object
# type             object
# title            object
# director         object
# cast             object
# country          object
# date_added       object
# release_year    float64
# rating           object
# duration         object
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20000 entries, 0 to 19999
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       20000 non-null  object
#  1   type          20000 non-null  object
#  2   title         20000 non-null  object
#  3   director      12136 non-null  object
#  4   cast          15964 non-null  object
#  5   country       14570 non-null  object
#  6   date_added    16371 non-null  object
#  7   release_year  16745 non-null  float64
#  8   rating        16069 non-null  object
#  9   duration      16499 non-null  object
# dtypes: float64(1), object(9)
# memory usage: 1.5+ MB

# %%
df.describe()
# Out:
#        release_year
# count  16745.000000
# mean    2014.256972
# std        8.685029
# min     1925.000000
# 25%     2014.000000
# 50%     2017.000000
# 75%     2019.000000
# max     2021.000000

# %%
df.describe(include= 'object')
# Out:
#        show_id   type                        title      director         cast  \
# count    20000  20000                        20000         12136        15964
# unique   17500      4                         8623          3877         6351
# top     s12806  Movie  What Happened, Miss Simone?  Marcus Raboy  Samuel West
# freq         4  13216                           11            39           34
#
#               country       date_added rating  duration
# count           14570            16371  16069     16499
# unique            633             1637     17       212
# top     United States  January 1, 2020  TV-MA  1 Season
# freq             5120              216   5886      3437

# %%
df = pd.read_csv("amazon.csv")
print(df)
# Out:
#         user_id product_id     category subcategory    brand     price  \
# 0       U356787     P39256  Electronics      Mobile      H&M  33090.51
# 1       U198246     P38657       Sports     Outdoor  Samsung   9368.97
# 2       U539898     P38893       Sports     Fitness      H&M  14756.85
# 3       U325772     P54118       Beauty      Makeup     Sony    668.83
# 4       U865179     P70217         Home       Decor     Sony  10881.29
# ...         ...        ...          ...         ...      ...       ...
# 999995  U485987     P55818       Sports     Cycling     Sony   1478.80
# 999996  U917934     P59467       Sports     Cycling      H&M   4532.12
# 999997  U667215     P21840  Electronics      Laptop   Lenovo  14986.75
# 999998  U640883     P46092     Clothing         Men  Samsung   4473.67
# 999999  U220301     P91830  Electronics      Laptop  Samsung  71369.83
#
#         discount  final_price  rating  review_count  stock seller_id  \
# 0          10.46     29629.31     4.9            43     71     S2679
# 1           5.32      8870.73     3.9            13    119     S9279
# 2          26.00     10919.43     4.2            46    229     S5557
# 3          24.81       502.91     3.8             6     52     S2519
# 4          48.63      5589.58     4.0            48    274     S3045
# ...          ...          ...     ...           ...    ...       ...
# 999995     36.55       938.34     4.1            15    392     S7795
# 999996      5.22      4295.44     4.2            32     17     S4919
# 999997     29.00     10640.50     4.5           115    382     S4196
# 999998     21.43      3514.86     4.2            14    451     S3812
# 999999      8.25     65480.69     5.0            36    109     S1286
#
#         seller_rating purchase_date  shipping_time_days   location  \
# 0                 4.3    2025-03-04                   6  Bangalore
# 1                 4.9    2025-12-12                   1      Delhi
# 2                 4.9    2024-04-25                   1    Chennai
# 3                 3.1    2025-12-18                   2     Mumbai
# 4                 2.6    2024-05-16                   5      Delhi
# ...               ...           ...                 ...        ...
# 999995            4.2    2025-03-12                   1      Delhi
# 999996            3.6    2025-11-04                   5  Hyderabad
# 999997            2.8    2025-11-06                   5  Hyderabad
# 999998            2.9    2025-02-25                   1      Delhi
# 999999            2.8    2025-05-28                   5    Chennai
#
#             device payment_method  is_returned delivery_status
# 0           Tablet            UPI         True        Returned
# 1           Tablet            UPI         True        Returned
# 2       Mobile App    Credit Card         True        Returned
# 3              Web            UPI        False      In Transit
# 4              Web            UPI        False         Delayed
# ...            ...            ...          ...             ...
# 999995  Mobile App    Credit Card        False       Delivered
# 999996  Mobile App     Debit Card        False      In Transit
# 999997         Web     Debit Card        False      In Transit
# 999998      Tablet     Debit Card        False       Delivered
# 999999  Mobile App            UPI        False         Delayed
#
# [1000000 rows x 20 columns]

# %%
df.head(5)
# Out:
#    user_id product_id     category subcategory    brand     price  discount  \
# 0  U356787     P39256  Electronics      Mobile      H&M  33090.51     10.46
# 1  U198246     P38657       Sports     Outdoor  Samsung   9368.97      5.32
# 2  U539898     P38893       Sports     Fitness      H&M  14756.85     26.00
# 3  U325772     P54118       Beauty      Makeup     Sony    668.83     24.81
# 4  U865179     P70217         Home       Decor     Sony  10881.29     48.63
#
#    final_price  rating  review_count  stock seller_id  seller_rating  \
# 0     29629.31     4.9            43     71     S2679            4.3
# 1      8870.73     3.9            13    119     S9279            4.9
# 2     10919.43     4.2            46    229     S5557            4.9
# 3       502.91     3.8             6     52     S2519            3.1
# 4      5589.58     4.0            48    274     S3045            2.6
#
#   purchase_date  shipping_time_days   location      device payment_method  \
# 0    2025-03-04                   6  Bangalore      Tablet            UPI
# 1    2025-12-12                   1      Delhi      Tablet            UPI
# 2    2024-04-25                   1    Chennai  Mobile App    Credit Card
# 3    2025-12-18                   2     Mumbai         Web            UPI
# 4    2024-05-16                   5      Delhi         Web            UPI
#
#    is_returned delivery_status
# 0         True        Returned
# 1         True        Returned
# 2         True        Returned
# 3        False      In Transit
# 4        False         Delayed

# %%
df.tail(5)
# Out:
#         user_id product_id     category subcategory    brand     price  \
# 999995  U485987     P55818       Sports     Cycling     Sony   1478.80
# 999996  U917934     P59467       Sports     Cycling      H&M   4532.12
# 999997  U667215     P21840  Electronics      Laptop   Lenovo  14986.75
# 999998  U640883     P46092     Clothing         Men  Samsung   4473.67
# 999999  U220301     P91830  Electronics      Laptop  Samsung  71369.83
#
#         discount  final_price  rating  review_count  stock seller_id  \
# 999995     36.55       938.34     4.1            15    392     S7795
# 999996      5.22      4295.44     4.2            32     17     S4919
# 999997     29.00     10640.50     4.5           115    382     S4196
# 999998     21.43      3514.86     4.2            14    451     S3812
# 999999      8.25     65480.69     5.0            36    109     S1286
#
#         seller_rating purchase_date  shipping_time_days   location  \
# 999995            4.2    2025-03-12                   1      Delhi
# 999996            3.6    2025-11-04                   5  Hyderabad
# 999997            2.8    2025-11-06                   5  Hyderabad
# 999998            2.9    2025-02-25                   1      Delhi
# 999999            2.8    2025-05-28                   5    Chennai
#
#             device payment_method  is_returned delivery_status
# 999995  Mobile App    Credit Card        False       Delivered
# 999996  Mobile App     Debit Card        False      In Transit
# 999997         Web     Debit Card        False      In Transit
# 999998      Tablet     Debit Card        False       Delivered
# 999999  Mobile App            UPI        False         Delayed

# %%
df.sample(10)
# Out:
#         user_id product_id  category subcategory   brand     price  discount  \
# 172911  U108883     P13551  Clothing       Women    Sony   3684.35     15.07
# 826699  U174827     P20960    Sports     Cycling     H&M   3989.89     20.14
# 93674   U173753     P10299    Sports     Fitness    Boat   3591.61     23.53
# 629210  U275217     P43738    Beauty      Makeup   Apple   4770.07      8.92
# 209762  U330093     P72567    Sports     Outdoor     H&M  11810.49     31.58
# 880031  U928417     P35154    Beauty      Makeup      HP   4164.38     24.75
# 362372  U390467     P61973    Sports     Outdoor  Lenovo   2169.04     16.33
# 417598  U903804     P50135  Clothing         Men    Zara   1657.35     54.85
# 217677  U580578     P15158      Home       Decor    Puma  16246.60     47.74
# 634591  U673287     P19993      Home   Furniture   Apple   9044.48     19.89
#
#         final_price  rating  review_count  stock seller_id  seller_rating  \
# 172911      3129.30     2.7            11     85     S7961            3.0
# 826699      3186.40     4.1            26    258     S6857            3.2
# 93674       2746.51     4.1            36    108     S5572            4.7
# 629210      4344.75     4.5            13     61     S1478            2.9
# 209762      8080.65     3.7            55    448     S7546            4.3
# 880031      3133.59     5.0            85    341     S1246            4.1
# 362372      1814.85     4.4             7    437     S5715            4.8
# 417598       748.37     4.0            10     54     S7006            3.5
# 217677      8489.92     4.0             5    406     S3338            3.3
# 634591      7245.94     3.6             4     37     S8995            4.4
#
#        purchase_date  shipping_time_days   location      device  \
# 172911    2025-09-07                   2  Bangalore  Mobile App
# 826699    2026-03-27                   4    Chennai      Tablet
# 93674     2025-02-17                   3     Mumbai         Web
# 629210    2025-06-10                   1      Delhi  Mobile App
# 209762    2025-04-20                   5  Bangalore  Mobile App
# 880031    2025-02-15                   5     Mumbai  Mobile App
# 362372    2024-08-16                   4  Bangalore      Tablet
# 417598    2024-11-12                   6  Hyderabad      Tablet
# 217677    2024-12-14                   4    Chennai         Web
# 634591    2024-05-19                   6    Chennai      Tablet
#
#           payment_method  is_returned delivery_status
# 172911       Credit Card         True        Returned
# 826699  Cash on Delivery        False       Delivered
# 93674        Credit Card        False      In Transit
# 629210  Cash on Delivery        False         Delayed
# 209762       Credit Card        False       Delivered
# 880031               UPI        False      In Transit
# 362372               UPI        False      In Transit
# 417598  Cash on Delivery         True        Returned
# 217677        Debit Card        False         Delayed
# 634591        Debit Card        False         Delayed

# %%
df.info
# Out:
# <bound method DataFrame.info of         user_id product_id     category subcategory    brand     price  \
# 0       U356787     P39256  Electronics      Mobile      H&M  33090.51
# 1       U198246     P38657       Sports     Outdoor  Samsung   9368.97
# 2       U539898     P38893       Sports     Fitness      H&M  14756.85
# 3       U325772     P54118       Beauty      Makeup     Sony    668.83
# 4       U865179     P70217         Home       Decor     Sony  10881.29
# ...         ...        ...          ...         ...      ...       ...
# 999995  U485987     P55818       Sports     Cycling     Sony   1478.80
# 999996  U917934     P59467       Sports     Cycling      H&M   4532.12
# 999997  U667215     P21840  Electronics      Laptop   Lenovo  14986.75
# 999998  U640883     P46092     Clothing         Men  Samsung   4473.67
# 999999  U220301     P91830  Electronics      Laptop  Samsung  71369.83
#
#         discount  final_price  rating  review_count  stock seller_id  \
# 0          10.46     29629.31     4.9            43     71     S2679
# 1           5.32      8870.73     3.9            13    119     S9279
# 2          26.00     10919.43     4.2            46    229     S5557
# 3          24.81       502.91     3.8             6     52     S2519
# 4          48.63      5589.58     4.0            48    274     S3045
# ...          ...          ...     ...           ...    ...       ...
# 999995     36.55       938.34     4.1            15    392     S7795
# 999996      5.22      4295.44     4.2            32     17     S4919
# 999997     29.00     10640.50     4.5           115    382     S4196
# 999998     21.43      3514.86     4.2            14    451     S3812
# 999999      8.25     65480.69     5.0            36    109     S1286
#
#         seller_rating purchase_date  shipping_time_days   location  \
# 0                 4.3    2025-03-04                   6  Bangalore
# 1                 4.9    2025-12-12                   1      Delhi
# 2                 4.9    2024-04-25                   1    Chennai
# 3                 3.1    2025-12-18                   2     Mumbai
# 4                 2.6    2024-05-16                   5      Delhi
# ...               ...           ...                 ...        ...
# 999995            4.2    2025-03-12                   1      Delhi
# 999996            3.6    2025-11-04                   5  Hyderabad
# 999997            2.8    2025-11-06                   5  Hyderabad
# 999998            2.9    2025-02-25                   1      Delhi
# 999999            2.8    2025-05-28                   5    Chennai
#
#             device payment_method  is_returned delivery_status
# 0           Tablet            UPI         True        Returned
# 1           Tablet            UPI         True        Returned
# 2       Mobile App    Credit Card         True        Returned
# 3              Web            UPI        False      In Transit
# 4              Web            UPI        False         Delayed
# ...            ...            ...          ...             ...
# 999995  Mobile App    Credit Card        False       Delivered
# 999996  Mobile App     Debit Card        False      In Transit
# 999997         Web     Debit Card        False      In Transit
# 999998      Tablet     Debit Card        False       Delivered
# 999999  Mobile App            UPI        False         Delayed
#
# [1000000 rows x 20 columns]>

# %%
df.shape
# Out:
# (1000000, 20)

# %%
df.columns
# Out:
# Index(['user_id', 'product_id', 'category', 'subcategory', 'brand', 'price',
#        'discount', 'final_price', 'rating', 'review_count', 'stock',
#        'seller_id', 'seller_rating', 'purchase_date', 'shipping_time_days',
#        'location', 'device', 'payment_method', 'is_returned',
#        'delivery_status'],
#       dtype='object')

# %%
df.dtypes
# Out:
# user_id                object
# product_id             object
# category               object
# subcategory            object
# brand                  object
# price                 float64
# discount              float64
# final_price           float64
# rating                float64
# review_count            int64
# stock                   int64
# seller_id              object
# seller_rating         float64
# purchase_date          object
# shipping_time_days      int64
# location               object
# device                 object
# payment_method         object
# is_returned              bool
# delivery_status        object
# dtype: object

# %%
df.describe()
# Out:
#                 price        discount     final_price          rating  \
# count  1000000.000000  1000000.000000  1000000.000000  1000000.000000
# mean     13224.119093       28.996161     9938.876985        3.927226
# std      18079.626921       14.681077    14271.885557        0.519443
# min        200.030000        5.000000      101.460000        1.500000
# 25%       2700.147500       16.910000     1705.930000        3.600000
# 50%       4971.830000       28.070000     3790.795000        3.900000
# 75%      14134.482500       39.240000    10384.440000        4.300000
# max      79999.700000       70.000000    75831.110000        5.000000
#
#          review_count           stock   seller_rating  shipping_time_days
# count  1000000.000000  1000000.000000  1000000.000000      1000000.000000
# mean        32.626704      250.023345        3.750030            3.166389
# std         43.382201      144.567038        0.722092            1.674178
# min          0.000000        0.000000        2.500000            1.000000
# 25%         10.000000      125.000000        3.100000            2.000000
# 50%         20.000000      250.000000        3.800000            3.000000
# 75%         39.000000      375.000000        4.400000            5.000000
# max       3408.000000      500.000000        5.000000            6.000000

# %%
df.empty
# Out:
# False

# %%
import pandas as pd

# %%
df = pd.DataFrame({ " product": [ " laptop","phone","tv","coputer"],
                    "Quenty": [ 10,20,40,33],
                    "price":[ 4000,50000,6000,3000] })
print(df)
# Out:
#    product  Quenty  price
# 0   laptop      10   4000
# 1    phone      20  50000
# 2       tv      40   6000
# 3  coputer      33   3000

# %%
df[df ["price"]>4000]
print(df[df["price"]>4000])
# Out:
#    product  Quenty  price
# 1    phone      20  50000
# 2       tv      40   6000

# %%
df[df["Quenty"]>20]
print(df[df["Quenty"]>20])
# Out:
#    product  Quenty  price
# 2       tv      40   6000
# 3  coputer      33   3000

# %%
print(df[" product"])
# Out:
# 0     laptop
# 1      phone
# 2         tv
# 3    coputer
# Name:  product, dtype: object

# %%
df = pd.DataFrame({
    "Product": ["Laptop", "Notebook", "Book", "Mouse", "Book Stand", "Keyboard"],
    "City": ["Jaipur", "Delhi", "Mumbai", "Jaipur", "Delhi", "Pune"],
    "Sales": [50000, 8000, 8000, 3000, 12000, 15000],
    "Rating": [4.5, 4.0, 4.7, 3.8, 4.5, 4.1],
})
    "Index":[101,102,103,104,105,106]


print(df)
# Out:
#   Cell In[37], line 7
#     "Index":[101,102,103,104,105,106]
#     ^
# IndentationError: unexpected indent

# %%
print(df[(df["Sales"] > 10000) & (df["Rating"] > 3)])
# Out:
#       Product    City  Sales  Rating
# 0      Laptop  Jaipur  50000     4.5
# 4  Book Stand   Delhi  12000     4.5
# 5    Keyboard    Pune  15000     4.1

# %%
print(df.loc[101])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\range.py:413, in RangeIndex.get_loc(self, key)
#     412 try:
# --> 413     return self._range.index(new_key)
#     414 except ValueError as err:
#
# ValueError: 101 is not in range
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[35], line 1
# ----> 1 print(df.loc[101])
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexing.py:1192, in _LocationIndexer.__getitem__(self, key)
#    1190 maybe_callable = com.apply_if_callable(key, self.obj)
#    1191 maybe_callable = self._check_deprecated_callable_usage(key, maybe_callable)
# -> 1192 return self._getitem_axis(maybe_callable, axis=axis)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexing.py:1432, in _LocIndexer._getitem_axis(self, key, axis)
#    1430 # fall thru to straight lookup
#    1431 self._validate_key(key, axis)
# -> 1432 return self._get_label(key, axis=axis)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexing.py:1382, in _LocIndexer._get_label(self, label, axis)
#    1380 def _get_label(self, label, axis: AxisInt):
#    1381     # GH#5567 this will fail if the label is not present in the axis.
# -> 1382     return self.obj.xs(label, axis=axis)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\generic.py:4323, in NDFrame.xs(self, key, axis, level, drop_level)
#    4321             new_index = index[loc]
#    4322 else:
# -> 4323     loc = index.get_loc(key)
#    4325     if isinstance(loc, np.ndarray):
#    4326         if loc.dtype == np.bool_:
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\range.py:415, in RangeIndex.get_loc(self, key)
#     413         return self._range.index(new_key)
#     414     except ValueError as err:
# --> 415         raise KeyError(key) from err
#     416 if isinstance(key, Hashable):
#     417     raise KeyError(key)
#
# KeyError: 101

# %%
import pandas as pd

df = pd.DataFrame({
    "Order_ID": range(1001, 1051),

    "Product": [
        "Laptop", "Mouse", "Keyboard", "Notebook", "Monitor",
        "Book Stand", "Headphones", "Printer", "Tablet", "Pen Drive",
        "Laptop Bag", "Book", "Webcam", "Chair", "Desk",
        "Notebook", "Mouse Pad", "Keyboard", "Laptop", "Monitor",
        "Book Shelf", "Headphones", "Printer", "Tablet", "Pen",
        "Laptop Bag", "Book", "Webcam", "Chair", "Desk",
        "Keyboard", "Mouse", "Laptop", "Notebook", "Monitor",
        "Book Stand", "Printer", "Headphones", "Tablet", "Pen Drive",
        "Laptop", "Book", "Webcam", "Chair", "Desk",
        "Mouse Pad", "Keyboard", "Monitor", "Notebook", "Laptop"
    ],

    "Category": [
        "Electronics", "Accessories", "Accessories", "Books", "Electronics",
        "Books", "Electronics", "Electronics", "Electronics", "Accessories",
        "Accessories", "Books", "Electronics", "Furniture", "Furniture",
        "Books", "Accessories", "Accessories", "Electronics", "Electronics",
        "Books", "Electronics", "Electronics", "Electronics", "Accessories",
        "Accessories", "Books", "Electronics", "Furniture", "Furniture",
        "Accessories", "Accessories", "Electronics", "Books", "Electronics",
        "Books", "Electronics", "Electronics", "Electronics", "Accessories",
        "Electronics", "Books", "Electronics", "Furniture", "Furniture",
        "Accessories", "Accessories", "Electronics", "Books", "Electronics"
    ],

    "City": [
        "Jaipur", "Delhi", "Mumbai", "Pune", "Jaipur",
        "Delhi", "Mumbai", "Kolkata", "Pune", "Jaipur",
        "Delhi", "Mumbai", "Pune", "Jaipur", "Delhi",
        "Kolkata", "Mumbai", "Jaipur", "Delhi", "Pune",
        "Mumbai", "Kolkata", "Jaipur", "Delhi", "Pune",
        "Mumbai", "Jaipur", "Delhi", "Kolkata", "Pune",
        "Jaipur", "Delhi", "Mumbai", "Pune", "Kolkata",
        "Jaipur", "Delhi", "Mumbai", "Pune", "Kolkata",
        "Delhi", "Mumbai", "Jaipur", "Pune", "Kolkata",
        "Jaipur", "Delhi", "Mumbai", "Pune", "Jaipur"
    ],

    "Sales": [
        55000, 2500, 4500, 1800, 32000,
        6500, 8500, 22000, 28000, 4000,
        7500, 3500, 9500, 15000, 12000,
        2500, 1800, 5000, 48000, 27000,
        7000, 9000, 21000, 26000, 1200,
        6500, 3200, 11000, 14500, 13000,
        5200, 2800, 60000, 2200, 30000,
        5500, 19500, 10500, 24000, 3500,
        45000, 4000, 12500, 16000, 14000,
        3000, 4800, 29000, 2000, 68000
    ],

    "Quantity": [
        5, 10, 8, 15, 4,
        6, 7, 3, 5, 9,
        6, 12, 7, 3, 4,
        5, 10, 8, 6, 4,
        7, 6, 3, 5, 15,
        8, 10, 6, 4, 5,
        8, 12, 5, 14, 4,
        9, 3, 5, 7, 10,
        4, 8, 5, 3, 6,
        11, 7, 4, 12, 6
    ],

    "Rating": [
        4.5, 4.0, 3.8, 4.2, 4.7,
        4.1, 4.3, 3.9, 4.6, 3.7,
        4.2, 4.0, 4.4, 4.5, 3.8,
        4.1, 3.9, 4.0, 4.8, 4.5,
        4.2, 4.1, 3.8, 4.6, 3.5,
        4.0, 4.3, 4.5, 3.9, 4.1,
        4.0, 3.8, 4.9, 4.2, 4.7,
        4.1, 3.9, 4.4, 4.6, 3.7,
        4.8, 4.0, 4.3, 4.5, 4.1,
        3.9, 4.2, 4.7, 4.0, 4.9
    ],

    "Payment_Mode": [
        "UPI", "Cash", "Card", "UPI", "Card",
        "Cash", "UPI", "Card", "UPI", "Cash",
        "Card", "UPI", "Cash", "Card", "UPI",
        "Cash", "Card", "UPI", "Card", "Cash",
        "UPI", "Card", "Cash", "UPI", "Card",
        "Cash", "UPI", "Card", "Cash", "UPI",
        "Card", "Cash", "UPI", "Card", "Cash",
        "UPI", "Card", "Cash", "UPI", "Card",
        "Cash", "UPI", "Card", "Cash", "UPI",
        "Card", "Cash", "UPI", "Card", "Cash"
    ]
})

print(df)
# Out:
#     Order_ID     Product     Category     City  Sales  Quantity  Rating  \
# 0       1001      Laptop  Electronics   Jaipur  55000         5     4.5
# 1       1002       Mouse  Accessories    Delhi   2500        10     4.0
# 2       1003    Keyboard  Accessories   Mumbai   4500         8     3.8
# 3       1004    Notebook        Books     Pune   1800        15     4.2
# 4       1005     Monitor  Electronics   Jaipur  32000         4     4.7
# 5       1006  Book Stand        Books    Delhi   6500         6     4.1
# 6       1007  Headphones  Electronics   Mumbai   8500         7     4.3
# 7       1008     Printer  Electronics  Kolkata  22000         3     3.9
# 8       1009      Tablet  Electronics     Pune  28000         5     4.6
# 9       1010   Pen Drive  Accessories   Jaipur   4000         9     3.7
# 10      1011  Laptop Bag  Accessories    Delhi   7500         6     4.2
# 11      1012        Book        Books   Mumbai   3500        12     4.0
# 12      1013      Webcam  Electronics     Pune   9500         7     4.4
# 13      1014       Chair    Furniture   Jaipur  15000         3     4.5
# 14      1015        Desk    Furniture    Delhi  12000         4     3.8
# 15      1016    Notebook        Books  Kolkata   2500         5     4.1
# 16      1017   Mouse Pad  Accessories   Mumbai   1800        10     3.9
# 17      1018    Keyboard  Accessories   Jaipur   5000         8     4.0
# 18      1019      Laptop  Electronics    Delhi  48000         6     4.8
# 19      1020     Monitor  Electronics     Pune  27000         4     4.5
# 20      1021  Book Shelf        Books   Mumbai   7000         7     4.2
# 21      1022  Headphones  Electronics  Kolkata   9000         6     4.1
# 22      1023     Printer  Electronics   Jaipur  21000         3     3.8
# 23      1024      Tablet  Electronics    Delhi  26000         5     4.6
# 24      1025         Pen  Accessories     Pune   1200        15     3.5
# 25      1026  Laptop Bag  Accessories   Mumbai   6500         8     4.0
# 26      1027        Book        Books   Jaipur   3200        10     4.3
# 27      1028      Webcam  Electronics    Delhi  11000         6     4.5
# 28      1029       Chair    Furniture  Kolkata  14500         4     3.9
# 29      1030        Desk    Furniture     Pune  13000         5     4.1
# 30      1031    Keyboard  Accessories   Jaipur   5200         8     4.0
# 31      1032       Mouse  Accessories    Delhi   2800        12     3.8
# 32      1033      Laptop  Electronics   Mumbai  60000         5     4.9
# 33      1034    Notebook        Books     Pune   2200        14     4.2
# 34      1035     Monitor  Electronics  Kolkata  30000         4     4.7
# 35      1036  Book Stand        Books   Jaipur   5500         9     4.1
# 36      1037     Printer  Electronics    Delhi  19500         3     3.9
# 37      1038  Headphones  Electronics   Mumbai  10500         5     4.4
# 38      1039      Tablet  Electronics     Pune  24000         7     4.6
# 39      1040   Pen Drive  Accessories  Kolkata   3500        10     3.7
# 40      1041      Laptop  Electronics    Delhi  45000         4     4.8
# 41      1042        Book        Books   Mumbai   4000         8     4.0
# 42      1043      Webcam  Electronics   Jaipur  12500         5     4.3
# 43      1044       Chair    Furniture     Pune  16000         3     4.5
# 44      1045        Desk    Furniture  Kolkata  14000         6     4.1
# 45      1046   Mouse Pad  Accessories   Jaipur   3000        11     3.9
# 46      1047    Keyboard  Accessories    Delhi   4800         7     4.2
# 47      1048     Monitor  Electronics   Mumbai  29000         4     4.7
# 48      1049    Notebook        Books     Pune   2000        12     4.0
# 49      1050      Laptop  Electronics   Jaipur  68000         6     4.9
#
#    Payment_Mode
# 0           UPI
# 1          Cash
# 2          Card
# 3           UPI
# 4          Card
# 5          Cash
# 6           UPI
# 7          Card
# 8           UPI
# 9          Cash
# 10         Card
# 11          UPI
# 12         Cash
# 13         Card
# 14          UPI
# 15         Cash
# 16         Card
# 17          UPI
# 18         Card
# 19         Cash
# 20          UPI
# 21         Card
# 22         Cash
# 23          UPI
# 24         Card
# 25         Cash
# 26          UPI
# 27         Card
# 28         Cash
# 29          UPI
# 30         Card
# 31         Cash
# 32          UPI
# 33         Card
# 34         Cash
# 35          UPI
# 36         Card
# 37         Cash
# 38          UPI
# 39         Card
# 40         Cash
# 41          UPI
# 42         Card
# 43         Cash
# 44          UPI
# 45         Card
# 46         Cash
# 47          UPI
# 48         Card
# 49         Cash

# %%
df[df['Sales'] >10000]
# Out:
#     Order_ID     Product     Category     City  Sales  Quantity  Rating  \
# 0       1001      Laptop  Electronics   Jaipur  55000         5     4.5
# 4       1005     Monitor  Electronics   Jaipur  32000         4     4.7
# 7       1008     Printer  Electronics  Kolkata  22000         3     3.9
# 8       1009      Tablet  Electronics     Pune  28000         5     4.6
# 13      1014       Chair    Furniture   Jaipur  15000         3     4.5
# 14      1015        Desk    Furniture    Delhi  12000         4     3.8
# 18      1019      Laptop  Electronics    Delhi  48000         6     4.8
# 19      1020     Monitor  Electronics     Pune  27000         4     4.5
# 22      1023     Printer  Electronics   Jaipur  21000         3     3.8
# 23      1024      Tablet  Electronics    Delhi  26000         5     4.6
# 27      1028      Webcam  Electronics    Delhi  11000         6     4.5
# 28      1029       Chair    Furniture  Kolkata  14500         4     3.9
# 29      1030        Desk    Furniture     Pune  13000         5     4.1
# 32      1033      Laptop  Electronics   Mumbai  60000         5     4.9
# 34      1035     Monitor  Electronics  Kolkata  30000         4     4.7
# 36      1037     Printer  Electronics    Delhi  19500         3     3.9
# 37      1038  Headphones  Electronics   Mumbai  10500         5     4.4
# 38      1039      Tablet  Electronics     Pune  24000         7     4.6
# 40      1041      Laptop  Electronics    Delhi  45000         4     4.8
# 42      1043      Webcam  Electronics   Jaipur  12500         5     4.3
# 43      1044       Chair    Furniture     Pune  16000         3     4.5
# 44      1045        Desk    Furniture  Kolkata  14000         6     4.1
# 47      1048     Monitor  Electronics   Mumbai  29000         4     4.7
# 49      1050      Laptop  Electronics   Jaipur  68000         6     4.9
#
#    Payment_Mode
# 0           UPI
# 4          Card
# 7          Card
# 8           UPI
# 13         Card
# 14          UPI
# 18         Card
# 19         Cash
# 22         Cash
# 23          UPI
# 27         Card
# 28         Cash
# 29          UPI
# 32          UPI
# 34         Cash
# 36         Card
# 37         Cash
# 38          UPI
# 40         Cash
# 42         Card
# 43         Cash
# 44          UPI
# 47          UPI
# 49         Cash

# %%
df[df['City'] == 'Jaipur']
# Out:
#     Order_ID     Product     Category    City  Sales  Quantity  Rating  \
# 0       1001      Laptop  Electronics  Jaipur  55000         5     4.5
# 4       1005     Monitor  Electronics  Jaipur  32000         4     4.7
# 9       1010   Pen Drive  Accessories  Jaipur   4000         9     3.7
# 13      1014       Chair    Furniture  Jaipur  15000         3     4.5
# 17      1018    Keyboard  Accessories  Jaipur   5000         8     4.0
# 22      1023     Printer  Electronics  Jaipur  21000         3     3.8
# 26      1027        Book        Books  Jaipur   3200        10     4.3
# 30      1031    Keyboard  Accessories  Jaipur   5200         8     4.0
# 35      1036  Book Stand        Books  Jaipur   5500         9     4.1
# 42      1043      Webcam  Electronics  Jaipur  12500         5     4.3
# 45      1046   Mouse Pad  Accessories  Jaipur   3000        11     3.9
# 49      1050      Laptop  Electronics  Jaipur  68000         6     4.9
#
#    Payment_Mode
# 0           UPI
# 4          Card
# 9          Cash
# 13         Card
# 17          UPI
# 22         Cash
# 26          UPI
# 30         Card
# 35          UPI
# 42         Card
# 45         Card
# 49         Cash

# %%
df[df["Rating"] >=4.5]
# Out:
#     Order_ID  Product     Category     City  Sales  Quantity  Rating  \
# 0       1001   Laptop  Electronics   Jaipur  55000         5     4.5
# 4       1005  Monitor  Electronics   Jaipur  32000         4     4.7
# 8       1009   Tablet  Electronics     Pune  28000         5     4.6
# 13      1014    Chair    Furniture   Jaipur  15000         3     4.5
# 18      1019   Laptop  Electronics    Delhi  48000         6     4.8
# 19      1020  Monitor  Electronics     Pune  27000         4     4.5
# 23      1024   Tablet  Electronics    Delhi  26000         5     4.6
# 27      1028   Webcam  Electronics    Delhi  11000         6     4.5
# 32      1033   Laptop  Electronics   Mumbai  60000         5     4.9
# 34      1035  Monitor  Electronics  Kolkata  30000         4     4.7
# 38      1039   Tablet  Electronics     Pune  24000         7     4.6
# 40      1041   Laptop  Electronics    Delhi  45000         4     4.8
# 43      1044    Chair    Furniture     Pune  16000         3     4.5
# 47      1048  Monitor  Electronics   Mumbai  29000         4     4.7
# 49      1050   Laptop  Electronics   Jaipur  68000         6     4.9
#
#    Payment_Mode
# 0           UPI
# 4          Card
# 8           UPI
# 13         Card
# 18         Card
# 19         Cash
# 23          UPI
# 27         Card
# 32          UPI
# 34         Cash
# 38          UPI
# 40         Cash
# 43         Cash
# 47          UPI
# 49         Cash

# %%
df[df['Category'] == 'Electronics']
# Out:
#     Order_ID     Product     Category     City  Sales  Quantity  Rating  \
# 0       1001      Laptop  Electronics   Jaipur  55000         5     4.5
# 4       1005     Monitor  Electronics   Jaipur  32000         4     4.7
# 6       1007  Headphones  Electronics   Mumbai   8500         7     4.3
# 7       1008     Printer  Electronics  Kolkata  22000         3     3.9
# 8       1009      Tablet  Electronics     Pune  28000         5     4.6
# 12      1013      Webcam  Electronics     Pune   9500         7     4.4
# 18      1019      Laptop  Electronics    Delhi  48000         6     4.8
# 19      1020     Monitor  Electronics     Pune  27000         4     4.5
# 21      1022  Headphones  Electronics  Kolkata   9000         6     4.1
# 22      1023     Printer  Electronics   Jaipur  21000         3     3.8
# 23      1024      Tablet  Electronics    Delhi  26000         5     4.6
# 27      1028      Webcam  Electronics    Delhi  11000         6     4.5
# 32      1033      Laptop  Electronics   Mumbai  60000         5     4.9
# 34      1035     Monitor  Electronics  Kolkata  30000         4     4.7
# 36      1037     Printer  Electronics    Delhi  19500         3     3.9
# 37      1038  Headphones  Electronics   Mumbai  10500         5     4.4
# 38      1039      Tablet  Electronics     Pune  24000         7     4.6
# 40      1041      Laptop  Electronics    Delhi  45000         4     4.8
# 42      1043      Webcam  Electronics   Jaipur  12500         5     4.3
# 47      1048     Monitor  Electronics   Mumbai  29000         4     4.7
# 49      1050      Laptop  Electronics   Jaipur  68000         6     4.9
#
#    Payment_Mode
# 0           UPI
# 4          Card
# 6           UPI
# 7          Card
# 8           UPI
# 12         Cash
# 18         Card
# 19         Cash
# 21         Card
# 22         Cash
# 23          UPI
# 27         Card
# 32          UPI
# 34         Cash
# 36         Card
# 37         Cash
# 38          UPI
# 40         Cash
# 42         Card
# 47          UPI
# 49         Cash

# %%
print(df[(df["Sales"] > 10000) & (df["Rating"] > 4.0)])
# Out:
#     Order_ID     Product     Category     City  Sales  Quantity  Rating  \
# 0       1001      Laptop  Electronics   Jaipur  55000         5     4.5
# 4       1005     Monitor  Electronics   Jaipur  32000         4     4.7
# 8       1009      Tablet  Electronics     Pune  28000         5     4.6
# 13      1014       Chair    Furniture   Jaipur  15000         3     4.5
# 18      1019      Laptop  Electronics    Delhi  48000         6     4.8
# 19      1020     Monitor  Electronics     Pune  27000         4     4.5
# 23      1024      Tablet  Electronics    Delhi  26000         5     4.6
# 27      1028      Webcam  Electronics    Delhi  11000         6     4.5
# 29      1030        Desk    Furniture     Pune  13000         5     4.1
# 32      1033      Laptop  Electronics   Mumbai  60000         5     4.9
# 34      1035     Monitor  Electronics  Kolkata  30000         4     4.7
# 37      1038  Headphones  Electronics   Mumbai  10500         5     4.4
# 38      1039      Tablet  Electronics     Pune  24000         7     4.6
# 40      1041      Laptop  Electronics    Delhi  45000         4     4.8
# 42      1043      Webcam  Electronics   Jaipur  12500         5     4.3
# 43      1044       Chair    Furniture     Pune  16000         3     4.5
# 44      1045        Desk    Furniture  Kolkata  14000         6     4.1
# 47      1048     Monitor  Electronics   Mumbai  29000         4     4.7
# 49      1050      Laptop  Electronics   Jaipur  68000         6     4.9
#
#    Payment_Mode
# 0           UPI
# 4          Card
# 8           UPI
# 13         Card
# 18         Card
# 19         Cash
# 23          UPI
# 27         Card
# 29          UPI
# 32          UPI
# 34         Cash
# 37         Cash
# 38          UPI
# 40         Cash
# 42         Card
# 43         Cash
# 44          UPI
# 47          UPI
# 49         Cash

# %%
print(df[(df["Sales"] > 20000) & (df["Quantity"] > 5)])
# Out:
#     Order_ID Product     Category    City  Sales  Quantity  Rating  \
# 18      1019  Laptop  Electronics   Delhi  48000         6     4.8
# 38      1039  Tablet  Electronics    Pune  24000         7     4.6
# 49      1050  Laptop  Electronics  Jaipur  68000         6     4.9
#
#    Payment_Mode
# 18         Card
# 38          UPI
# 49         Cash

# %%
print(df[(df["Category"] == "Electronics") & (df["Sales"] > 15000)])
# Out:
#     Order_ID  Product     Category     City  Sales  Quantity  Rating  \
# 0       1001   Laptop  Electronics   Jaipur  55000         5     4.5
# 4       1005  Monitor  Electronics   Jaipur  32000         4     4.7
# 7       1008  Printer  Electronics  Kolkata  22000         3     3.9
# 8       1009   Tablet  Electronics     Pune  28000         5     4.6
# 18      1019   Laptop  Electronics    Delhi  48000         6     4.8
# 19      1020  Monitor  Electronics     Pune  27000         4     4.5
# 22      1023  Printer  Electronics   Jaipur  21000         3     3.8
# 23      1024   Tablet  Electronics    Delhi  26000         5     4.6
# 32      1033   Laptop  Electronics   Mumbai  60000         5     4.9
# 34      1035  Monitor  Electronics  Kolkata  30000         4     4.7
# 36      1037  Printer  Electronics    Delhi  19500         3     3.9
# 38      1039   Tablet  Electronics     Pune  24000         7     4.6
# 40      1041   Laptop  Electronics    Delhi  45000         4     4.8
# 47      1048  Monitor  Electronics   Mumbai  29000         4     4.7
# 49      1050   Laptop  Electronics   Jaipur  68000         6     4.9
#
#    Payment_Mode
# 0           UPI
# 4          Card
# 7          Card
# 8           UPI
# 18         Card
# 19         Cash
# 22         Cash
# 23          UPI
# 32          UPI
# 34         Cash
# 36         Card
# 38          UPI
# 40         Cash
# 47          UPI
# 49         Cash

# %%
print(df[(df["City"] == "Jaipur") & (df["Rating"] >=4.5)])
# Out:
#     Order_ID  Product     Category    City  Sales  Quantity  Rating  \
# 0       1001   Laptop  Electronics  Jaipur  55000         5     4.5
# 4       1005  Monitor  Electronics  Jaipur  32000         4     4.7
# 13      1014    Chair    Furniture  Jaipur  15000         3     4.5
# 49      1050   Laptop  Electronics  Jaipur  68000         6     4.9
#
#    Payment_Mode
# 0           UPI
# 4          Card
# 13         Card
# 49         Cash

# %%
print(df[(df["Category"] == "Electronics") | (df["Category"] == "Books")])
# Out:
#     Order_ID     Product     Category     City  Sales  Quantity  Rating  \
# 0       1001      Laptop  Electronics   Jaipur  55000         5     4.5
# 3       1004    Notebook        Books     Pune   1800        15     4.2
# 4       1005     Monitor  Electronics   Jaipur  32000         4     4.7
# 5       1006  Book Stand        Books    Delhi   6500         6     4.1
# 6       1007  Headphones  Electronics   Mumbai   8500         7     4.3
# 7       1008     Printer  Electronics  Kolkata  22000         3     3.9
# 8       1009      Tablet  Electronics     Pune  28000         5     4.6
# 11      1012        Book        Books   Mumbai   3500        12     4.0
# 12      1013      Webcam  Electronics     Pune   9500         7     4.4
# 15      1016    Notebook        Books  Kolkata   2500         5     4.1
# 18      1019      Laptop  Electronics    Delhi  48000         6     4.8
# 19      1020     Monitor  Electronics     Pune  27000         4     4.5
# 20      1021  Book Shelf        Books   Mumbai   7000         7     4.2
# 21      1022  Headphones  Electronics  Kolkata   9000         6     4.1
# 22      1023     Printer  Electronics   Jaipur  21000         3     3.8
# 23      1024      Tablet  Electronics    Delhi  26000         5     4.6
# 26      1027        Book        Books   Jaipur   3200        10     4.3
# 27      1028      Webcam  Electronics    Delhi  11000         6     4.5
# 32      1033      Laptop  Electronics   Mumbai  60000         5     4.9
# 33      1034    Notebook        Books     Pune   2200        14     4.2
# 34      1035     Monitor  Electronics  Kolkata  30000         4     4.7
# 35      1036  Book Stand        Books   Jaipur   5500         9     4.1
# 36      1037     Printer  Electronics    Delhi  19500         3     3.9
# 37      1038  Headphones  Electronics   Mumbai  10500         5     4.4
# 38      1039      Tablet  Electronics     Pune  24000         7     4.6
# 40      1041      Laptop  Electronics    Delhi  45000         4     4.8
# 41      1042        Book        Books   Mumbai   4000         8     4.0
# 42      1043      Webcam  Electronics   Jaipur  12500         5     4.3
# 47      1048     Monitor  Electronics   Mumbai  29000         4     4.7
# 48      1049    Notebook        Books     Pune   2000        12     4.0
# 49      1050      Laptop  Electronics   Jaipur  68000         6     4.9
#
#    Payment_Mode
# 0           UPI
# 3           UPI
# 4          Card
# 5          Cash
# 6           UPI
# 7          Card
# 8           UPI
# 11          UPI
# 12         Cash
# 15         Cash
# 18         Card
# 19         Cash
# 20          UPI
# 21         Card
# 22         Cash
# 23          UPI
# 26          UPI
# 27         Card
# 32          UPI
# 33         Card
# 34         Cash
# 35          UPI
# 36         Card
# 37         Cash
# 38          UPI
# 40         Cash
# 41          UPI
# 42         Card
# 47          UPI
# 48         Card
# 49         Cash

# %%
print(df[(df["City"] == "Jaipur") | (df["City"] == "Delhi")])
# Out:
#     Order_ID     Product     Category    City  Sales  Quantity  Rating  \
# 0       1001      Laptop  Electronics  Jaipur  55000         5     4.5
# 1       1002       Mouse  Accessories   Delhi   2500        10     4.0
# 4       1005     Monitor  Electronics  Jaipur  32000         4     4.7
# 5       1006  Book Stand        Books   Delhi   6500         6     4.1
# 9       1010   Pen Drive  Accessories  Jaipur   4000         9     3.7
# 10      1011  Laptop Bag  Accessories   Delhi   7500         6     4.2
# 13      1014       Chair    Furniture  Jaipur  15000         3     4.5
# 14      1015        Desk    Furniture   Delhi  12000         4     3.8
# 17      1018    Keyboard  Accessories  Jaipur   5000         8     4.0
# 18      1019      Laptop  Electronics   Delhi  48000         6     4.8
# 22      1023     Printer  Electronics  Jaipur  21000         3     3.8
# 23      1024      Tablet  Electronics   Delhi  26000         5     4.6
# 26      1027        Book        Books  Jaipur   3200        10     4.3
# 27      1028      Webcam  Electronics   Delhi  11000         6     4.5
# 30      1031    Keyboard  Accessories  Jaipur   5200         8     4.0
# 31      1032       Mouse  Accessories   Delhi   2800        12     3.8
# 35      1036  Book Stand        Books  Jaipur   5500         9     4.1
# 36      1037     Printer  Electronics   Delhi  19500         3     3.9
# 40      1041      Laptop  Electronics   Delhi  45000         4     4.8
# 42      1043      Webcam  Electronics  Jaipur  12500         5     4.3
# 45      1046   Mouse Pad  Accessories  Jaipur   3000        11     3.9
# 46      1047    Keyboard  Accessories   Delhi   4800         7     4.2
# 49      1050      Laptop  Electronics  Jaipur  68000         6     4.9
#
#    Payment_Mode
# 0           UPI
# 1          Cash
# 4          Card
# 5          Cash
# 9          Cash
# 10         Card
# 13         Card
# 14          UPI
# 17          UPI
# 18         Card
# 22         Cash
# 23          UPI
# 26          UPI
# 27         Card
# 30         Card
# 31         Cash
# 35          UPI
# 36         Card
# 40         Cash
# 42         Card
# 45         Card
# 46         Cash
# 49         Cash

# %%
print(df[(df["Payment_Mode"] == "UPI") | (df["Payment_Mode"] == "Card")])
# Out:
#     Order_ID     Product     Category     City  Sales  Quantity  Rating  \
# 0       1001      Laptop  Electronics   Jaipur  55000         5     4.5
# 2       1003    Keyboard  Accessories   Mumbai   4500         8     3.8
# 3       1004    Notebook        Books     Pune   1800        15     4.2
# 4       1005     Monitor  Electronics   Jaipur  32000         4     4.7
# 6       1007  Headphones  Electronics   Mumbai   8500         7     4.3
# 7       1008     Printer  Electronics  Kolkata  22000         3     3.9
# 8       1009      Tablet  Electronics     Pune  28000         5     4.6
# 10      1011  Laptop Bag  Accessories    Delhi   7500         6     4.2
# 11      1012        Book        Books   Mumbai   3500        12     4.0
# 13      1014       Chair    Furniture   Jaipur  15000         3     4.5
# 14      1015        Desk    Furniture    Delhi  12000         4     3.8
# 16      1017   Mouse Pad  Accessories   Mumbai   1800        10     3.9
# 17      1018    Keyboard  Accessories   Jaipur   5000         8     4.0
# 18      1019      Laptop  Electronics    Delhi  48000         6     4.8
# 20      1021  Book Shelf        Books   Mumbai   7000         7     4.2
# 21      1022  Headphones  Electronics  Kolkata   9000         6     4.1
# 23      1024      Tablet  Electronics    Delhi  26000         5     4.6
# 24      1025         Pen  Accessories     Pune   1200        15     3.5
# 26      1027        Book        Books   Jaipur   3200        10     4.3
# 27      1028      Webcam  Electronics    Delhi  11000         6     4.5
# 29      1030        Desk    Furniture     Pune  13000         5     4.1
# 30      1031    Keyboard  Accessories   Jaipur   5200         8     4.0
# 32      1033      Laptop  Electronics   Mumbai  60000         5     4.9
# 33      1034    Notebook        Books     Pune   2200        14     4.2
# 35      1036  Book Stand        Books   Jaipur   5500         9     4.1
# 36      1037     Printer  Electronics    Delhi  19500         3     3.9
# 38      1039      Tablet  Electronics     Pune  24000         7     4.6
# 39      1040   Pen Drive  Accessories  Kolkata   3500        10     3.7
# 41      1042        Book        Books   Mumbai   4000         8     4.0
# 42      1043      Webcam  Electronics   Jaipur  12500         5     4.3
# 44      1045        Desk    Furniture  Kolkata  14000         6     4.1
# 45      1046   Mouse Pad  Accessories   Jaipur   3000        11     3.9
# 47      1048     Monitor  Electronics   Mumbai  29000         4     4.7
# 48      1049    Notebook        Books     Pune   2000        12     4.0
#
#    Payment_Mode
# 0           UPI
# 2          Card
# 3           UPI
# 4          Card
# 6           UPI
# 7          Card
# 8           UPI
# 10         Card
# 11          UPI
# 13         Card
# 14          UPI
# 16         Card
# 17          UPI
# 18         Card
# 20          UPI
# 21         Card
# 23          UPI
# 24         Card
# 26          UPI
# 27         Card
# 29          UPI
# 30         Card
# 32          UPI
# 33         Card
# 35          UPI
# 36         Card
# 38          UPI
# 39         Card
# 41          UPI
# 42         Card
# 44          UPI
# 45         Card
# 47          UPI
# 48         Card

# %%
print(df[(df["Category"] == "Furniture") | (df["Category"] == "Books")])
# Out:
#     Order_ID     Product   Category     City  Sales  Quantity  Rating  \
# 3       1004    Notebook      Books     Pune   1800        15     4.2
# 5       1006  Book Stand      Books    Delhi   6500         6     4.1
# 11      1012        Book      Books   Mumbai   3500        12     4.0
# 13      1014       Chair  Furniture   Jaipur  15000         3     4.5
# 14      1015        Desk  Furniture    Delhi  12000         4     3.8
# 15      1016    Notebook      Books  Kolkata   2500         5     4.1
# 20      1021  Book Shelf      Books   Mumbai   7000         7     4.2
# 26      1027        Book      Books   Jaipur   3200        10     4.3
# 28      1029       Chair  Furniture  Kolkata  14500         4     3.9
# 29      1030        Desk  Furniture     Pune  13000         5     4.1
# 33      1034    Notebook      Books     Pune   2200        14     4.2
# 35      1036  Book Stand      Books   Jaipur   5500         9     4.1
# 41      1042        Book      Books   Mumbai   4000         8     4.0
# 43      1044       Chair  Furniture     Pune  16000         3     4.5
# 44      1045        Desk  Furniture  Kolkata  14000         6     4.1
# 48      1049    Notebook      Books     Pune   2000        12     4.0
#
#    Payment_Mode
# 3           UPI
# 5          Cash
# 11          UPI
# 13         Card
# 14          UPI
# 15         Cash
# 20          UPI
# 26          UPI
# 28         Cash
# 29          UPI
# 33         Card
# 35          UPI
# 41          UPI
# 43         Cash
# 44          UPI
# 48         Card

# %%
print(df[(df["City"]).isin (["Jaipur","Delhi","Mumbai"])])
# Out:
#     Order_ID     Product     Category    City  Sales  Quantity  Rating  \
# 0       1001      Laptop  Electronics  Jaipur  55000         5     4.5
# 1       1002       Mouse  Accessories   Delhi   2500        10     4.0
# 2       1003    Keyboard  Accessories  Mumbai   4500         8     3.8
# 4       1005     Monitor  Electronics  Jaipur  32000         4     4.7
# 5       1006  Book Stand        Books   Delhi   6500         6     4.1
# 6       1007  Headphones  Electronics  Mumbai   8500         7     4.3
# 9       1010   Pen Drive  Accessories  Jaipur   4000         9     3.7
# 10      1011  Laptop Bag  Accessories   Delhi   7500         6     4.2
# 11      1012        Book        Books  Mumbai   3500        12     4.0
# 13      1014       Chair    Furniture  Jaipur  15000         3     4.5
# 14      1015        Desk    Furniture   Delhi  12000         4     3.8
# 16      1017   Mouse Pad  Accessories  Mumbai   1800        10     3.9
# 17      1018    Keyboard  Accessories  Jaipur   5000         8     4.0
# 18      1019      Laptop  Electronics   Delhi  48000         6     4.8
# 20      1021  Book Shelf        Books  Mumbai   7000         7     4.2
# 22      1023     Printer  Electronics  Jaipur  21000         3     3.8
# 23      1024      Tablet  Electronics   Delhi  26000         5     4.6
# 25      1026  Laptop Bag  Accessories  Mumbai   6500         8     4.0
# 26      1027        Book        Books  Jaipur   3200        10     4.3
# 27      1028      Webcam  Electronics   Delhi  11000         6     4.5
# 30      1031    Keyboard  Accessories  Jaipur   5200         8     4.0
# 31      1032       Mouse  Accessories   Delhi   2800        12     3.8
# 32      1033      Laptop  Electronics  Mumbai  60000         5     4.9
# 35      1036  Book Stand        Books  Jaipur   5500         9     4.1
# 36      1037     Printer  Electronics   Delhi  19500         3     3.9
# 37      1038  Headphones  Electronics  Mumbai  10500         5     4.4
# 40      1041      Laptop  Electronics   Delhi  45000         4     4.8
# 41      1042        Book        Books  Mumbai   4000         8     4.0
# 42      1043      Webcam  Electronics  Jaipur  12500         5     4.3
# 45      1046   Mouse Pad  Accessories  Jaipur   3000        11     3.9
# 46      1047    Keyboard  Accessories   Delhi   4800         7     4.2
# 47      1048     Monitor  Electronics  Mumbai  29000         4     4.7
# 49      1050      Laptop  Electronics  Jaipur  68000         6     4.9
#
#    Payment_Mode
# 0           UPI
# 1          Cash
# 2          Card
# 4          Card
# 5          Cash
# 6           UPI
# 9          Cash
# 10         Card
# 11          UPI
# 13         Card
# 14          UPI
# 16         Card
# 17          UPI
# 18         Card
# 20          UPI
# 22         Cash
# 23          UPI
# 25         Cash
# 26          UPI
# 27         Card
# 30         Card
# 31         Cash
# 32          UPI
# 35          UPI
# 36         Card
# 37         Cash
# 40         Cash
# 41          UPI
# 42         Card
# 45         Card
# 46         Cash
# 47          UPI
# 49         Cash

# %%
print(df[(df["Category"]).isin (["Electronics","Books","Accessories"])])
# Out:
#     Order_ID     Product     Category     City  Sales  Quantity  Rating  \
# 0       1001      Laptop  Electronics   Jaipur  55000         5     4.5
# 1       1002       Mouse  Accessories    Delhi   2500        10     4.0
# 2       1003    Keyboard  Accessories   Mumbai   4500         8     3.8
# 3       1004    Notebook        Books     Pune   1800        15     4.2
# 4       1005     Monitor  Electronics   Jaipur  32000         4     4.7
# 5       1006  Book Stand        Books    Delhi   6500         6     4.1
# 6       1007  Headphones  Electronics   Mumbai   8500         7     4.3
# 7       1008     Printer  Electronics  Kolkata  22000         3     3.9
# 8       1009      Tablet  Electronics     Pune  28000         5     4.6
# 9       1010   Pen Drive  Accessories   Jaipur   4000         9     3.7
# 10      1011  Laptop Bag  Accessories    Delhi   7500         6     4.2
# 11      1012        Book        Books   Mumbai   3500        12     4.0
# 12      1013      Webcam  Electronics     Pune   9500         7     4.4
# 15      1016    Notebook        Books  Kolkata   2500         5     4.1
# 16      1017   Mouse Pad  Accessories   Mumbai   1800        10     3.9
# 17      1018    Keyboard  Accessories   Jaipur   5000         8     4.0
# 18      1019      Laptop  Electronics    Delhi  48000         6     4.8
# 19      1020     Monitor  Electronics     Pune  27000         4     4.5
# 20      1021  Book Shelf        Books   Mumbai   7000         7     4.2
# 21      1022  Headphones  Electronics  Kolkata   9000         6     4.1
# 22      1023     Printer  Electronics   Jaipur  21000         3     3.8
# 23      1024      Tablet  Electronics    Delhi  26000         5     4.6
# 24      1025         Pen  Accessories     Pune   1200        15     3.5
# 25      1026  Laptop Bag  Accessories   Mumbai   6500         8     4.0
# 26      1027        Book        Books   Jaipur   3200        10     4.3
# 27      1028      Webcam  Electronics    Delhi  11000         6     4.5
# 30      1031    Keyboard  Accessories   Jaipur   5200         8     4.0
# 31      1032       Mouse  Accessories    Delhi   2800        12     3.8
# 32      1033      Laptop  Electronics   Mumbai  60000         5     4.9
# 33      1034    Notebook        Books     Pune   2200        14     4.2
# 34      1035     Monitor  Electronics  Kolkata  30000         4     4.7
# 35      1036  Book Stand        Books   Jaipur   5500         9     4.1
# 36      1037     Printer  Electronics    Delhi  19500         3     3.9
# 37      1038  Headphones  Electronics   Mumbai  10500         5     4.4
# 38      1039      Tablet  Electronics     Pune  24000         7     4.6
# 39      1040   Pen Drive  Accessories  Kolkata   3500        10     3.7
# 40      1041      Laptop  Electronics    Delhi  45000         4     4.8
# 41      1042        Book        Books   Mumbai   4000         8     4.0
# 42      1043      Webcam  Electronics   Jaipur  12500         5     4.3
# 45      1046   Mouse Pad  Accessories   Jaipur   3000        11     3.9
# 46      1047    Keyboard  Accessories    Delhi   4800         7     4.2
# 47      1048     Monitor  Electronics   Mumbai  29000         4     4.7
# 48      1049    Notebook        Books     Pune   2000        12     4.0
# 49      1050      Laptop  Electronics   Jaipur  68000         6     4.9
#
#    Payment_Mode
# 0           UPI
# 1          Cash
# 2          Card
# 3           UPI
# 4          Card
# 5          Cash
# 6           UPI
# 7          Card
# 8           UPI
# 9          Cash
# 10         Card
# 11          UPI
# 12         Cash
# 15         Cash
# 16         Card
# 17          UPI
# 18         Card
# 19         Cash
# 20          UPI
# 21         Card
# 22         Cash
# 23          UPI
# 24         Card
# 25         Cash
# 26          UPI
# 27         Card
# 30         Card
# 31         Cash
# 32          UPI
# 33         Card
# 34         Cash
# 35          UPI
# 36         Card
# 37         Cash
# 38          UPI
# 39         Card
# 40         Cash
# 41          UPI
# 42         Card
# 45         Card
# 46         Cash
# 47          UPI
# 48         Card
# 49         Cash

# %%
import pandas as pd

df = pd.DataFrame({
    "Employee": ["Aman", "Riya", "Neha", "Rahul", "Priya", "Karan", "Sneha", "Vikas"],
    "City": ["Jaipur", "Delhi", "Mumbai", "Jaipur", "Pune", "Delhi", "Mumbai", "Kota"],
    "Department": ["Sales", "HR", "IT", "Finance", "Sales", "IT", "HR", "Finance"],
    "Salary": [35000, 42000, 50000, 38000, 45000, 55000, 40000, 36000],
    "Experience": [2, 4, 5, 3, 4, 6, 3, 2],
    "Performance": [78, 85, 92, 74, 88, 95, 81, 76]
})

df.index = ["E101", "E102", "E103", "E104", "E105", "E106", "E107", "E108"]

print(df)
# Out:
#      Employee    City Department  Salary  Experience  Performance
# E101     Aman  Jaipur      Sales   35000           2           78
# E102     Riya   Delhi         HR   42000           4           85
# E103     Neha  Mumbai         IT   50000           5           92
# E104    Rahul  Jaipur    Finance   38000           3           74
# E105    Priya    Pune      Sales   45000           4           88
# E106    Karan   Delhi         IT   55000           6           95
# E107    Sneha  Mumbai         HR   40000           3           81
# E108    Vikas    Kota    Finance   36000           2           76

# %%
print(df.loc["E103","Employee"])
# Out:
# Neha

# %%
print(df.loc["E106","Salary"])
# Out:
# 55000

# %%
print(df.loc[["E106","E107"],["Salary","Employee"]])
# Out:
#       Salary Employee
# E106   55000    Karan
# E107   40000    Sneha

# %%
print(df.iloc[0])
# Out:
# Employee         Aman
# City           Jaipur
# Department      Sales
# Salary          35000
# Experience          2
# Performance        78
# Name: E101, dtype: object

# %%
print(df.iloc[4,3])
# Out:
# 45000

# %%
import pandas as pd
df.head['Salary']
print(df)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[5], line 2
#       1 import pandas as pd
# ----> 2 df.head['Salary']
#       3 print(df)
#
# TypeError: 'method' object is not subscriptable

# %%
import pandas as pd

data = {
    "Emp_ID": ["E101","E102","E103","E104","E105","E106",
               "E107","E108","E109","E110","E111","E112"],
    "Employee": ["Aman","Arya","Neha","Rahul","Priya","Karan",
                 "Sneha","Vikas","Anjali","Mohit","Pooja","Arjun"],
    "Department": ["Sales","HR","IT","Sales","Finance","IT",
                    "HR","Sales","Finance","IT","Sales","HR"],
    "City": ["Jaipur","Delhi","Mumbai","Jaipur","Pune","Delhi",
             "Mumbai","Pune","Delhi","Jaipur","Mumbai","Pune"],
    "Salary": [42000,52000,68000,47000,61000,75000,
               55000,49000,72000,65000,58000,45000],
    "Experience": [2,4,6,3,5,7,4,3,6,5,4,2],
    "Sales": [85000,72000,125000,91000,115000,138000,
              79000,102000,132000,119000,97000,68000],
    "Rating": [3.8,4.2,4.7,3.9,4.5,4.8,4.1,3.7,4.6,4.4,4.0,3.5]
}

df = pd.DataFrame(data)
print(df)
# Out:
#    Emp_ID Employee Department    City  Salary  Experience   Sales  Rating
# 0    E101     Aman      Sales  Jaipur   42000           2   85000     3.8
# 1    E102     Arya         HR   Delhi   52000           4   72000     4.2
# 2    E103     Neha         IT  Mumbai   68000           6  125000     4.7
# 3    E104    Rahul      Sales  Jaipur   47000           3   91000     3.9
# 4    E105    Priya    Finance    Pune   61000           5  115000     4.5
# 5    E106    Karan         IT   Delhi   75000           7  138000     4.8
# 6    E107    Sneha         HR  Mumbai   55000           4   79000     4.1
# 7    E108    Vikas      Sales    Pune   49000           3  102000     3.7
# 8    E109   Anjali    Finance   Delhi   72000           6  132000     4.6
# 9    E110    Mohit         IT  Jaipur   65000           5  119000     4.4
# 10   E111    Pooja      Sales  Mumbai   58000           4   97000     4.0
# 11   E112    Arjun         HR    Pune   45000           2   68000     3.5

# %%
df.sort_values(by='Salary',ascending=False)
# Out:
#    Emp_ID Employee Department    City  Salary  Experience   Sales  Rating
# 5    E106    Karan         IT   Delhi   75000           7  138000     4.8
# 8    E109   Anjali    Finance   Delhi   72000           6  132000     4.6
# 2    E103     Neha         IT  Mumbai   68000           6  125000     4.7
# 9    E110    Mohit         IT  Jaipur   65000           5  119000     4.4
# 4    E105    Priya    Finance    Pune   61000           5  115000     4.5
# 10   E111    Pooja      Sales  Mumbai   58000           4   97000     4.0
# 6    E107    Sneha         HR  Mumbai   55000           4   79000     4.1
# 1    E102     Arya         HR   Delhi   52000           4   72000     4.2
# 7    E108    Vikas      Sales    Pune   49000           3  102000     3.7
# 3    E104    Rahul      Sales  Jaipur   47000           3   91000     3.9
# 11   E112    Arjun         HR    Pune   45000           2   68000     3.5
# 0    E101     Aman      Sales  Jaipur   42000           2   85000     3.8

# %%
df.sort_values(by=["Department","Salary"],ascending=[True,False])
# Out:
#    Emp_ID Employee Department    City  Salary  Experience   Sales  Rating
# 8    E109   Anjali    Finance   Delhi   72000           6  132000     4.6
# 4    E105    Priya    Finance    Pune   61000           5  115000     4.5
# 6    E107    Sneha         HR  Mumbai   55000           4   79000     4.1
# 1    E102     Arya         HR   Delhi   52000           4   72000     4.2
# 11   E112    Arjun         HR    Pune   45000           2   68000     3.5
# 5    E106    Karan         IT   Delhi   75000           7  138000     4.8
# 2    E103     Neha         IT  Mumbai   68000           6  125000     4.7
# 9    E110    Mohit         IT  Jaipur   65000           5  119000     4.4
# 10   E111    Pooja      Sales  Mumbai   58000           4   97000     4.0
# 7    E108    Vikas      Sales    Pune   49000           3  102000     3.7
# 3    E104    Rahul      Sales  Jaipur   47000           3   91000     3.9
# 0    E101     Aman      Sales  Jaipur   42000           2   85000     3.8

# %%
df.sort_values(by="Sales",ascending=False).head(5)
# Out:
#   Emp_ID Employee Department    City  Salary  Experience   Sales  Rating
# 5   E106    Karan         IT   Delhi   75000           7  138000     4.8
# 8   E109   Anjali    Finance   Delhi   72000           6  132000     4.6
# 2   E103     Neha         IT  Mumbai   68000           6  125000     4.7
# 9   E110    Mohit         IT  Jaipur   65000           5  119000     4.4
# 4   E105    Priya    Finance    Pune   61000           5  115000     4.5

# %%
df.sort_values(by=["Rating","Experience"],ascending=[False,True])
# Out:
#    Emp_ID Employee Department    City  Salary  Experience   Sales  Rating
# 5    E106    Karan         IT   Delhi   75000           7  138000     4.8
# 2    E103     Neha         IT  Mumbai   68000           6  125000     4.7
# 8    E109   Anjali    Finance   Delhi   72000           6  132000     4.6
# 4    E105    Priya    Finance    Pune   61000           5  115000     4.5
# 9    E110    Mohit         IT  Jaipur   65000           5  119000     4.4
# 1    E102     Arya         HR   Delhi   52000           4   72000     4.2
# 6    E107    Sneha         HR  Mumbai   55000           4   79000     4.1
# 10   E111    Pooja      Sales  Mumbai   58000           4   97000     4.0
# 3    E104    Rahul      Sales  Jaipur   47000           3   91000     3.9
# 0    E101     Aman      Sales  Jaipur   42000           2   85000     3.8
# 7    E108    Vikas      Sales    Pune   49000           3  102000     3.7
# 11   E112    Arjun         HR    Pune   45000           2   68000     3.5

# %%
df.sort_values(by=["City","Sales"],ascending=[False,True])[["Employee","City","Sales"]]
# Out:
#    Employee    City   Sales
# 11    Arjun    Pune   68000
# 7     Vikas    Pune  102000
# 4     Priya    Pune  115000
# 6     Sneha  Mumbai   79000
# 10    Pooja  Mumbai   97000
# 2      Neha  Mumbai  125000
# 0      Aman  Jaipur   85000
# 3     Rahul  Jaipur   91000
# 9     Mohit  Jaipur  119000
# 1      Arya   Delhi   72000
# 8    Anjali   Delhi  132000
# 5     Karan   Delhi  138000

# %%
df.sort_values(by="Salary",ascending=False).tail(5)
# Out:
#    Emp_ID Employee Department    City  Salary  Experience   Sales  Rating
# 1    E102     Arya         HR   Delhi   52000           4   72000     4.2
# 7    E108    Vikas      Sales    Pune   49000           3  102000     3.7
# 3    E104    Rahul      Sales  Jaipur   47000           3   91000     3.9
# 11   E112    Arjun         HR    Pune   45000           2   68000     3.5
# 0    E101     Aman      Sales  Jaipur   42000           2   85000     3.8

# %%
df.loc["E103"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[30], line 1
# ----> 1 df.loc["E103"]
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexing.py:1192, in _LocationIndexer.__getitem__(self, key)
#    1190 maybe_callable = com.apply_if_callable(key, self.obj)
#    1191 maybe_callable = self._check_deprecated_callable_usage(key, maybe_callable)
# -> 1192 return self._getitem_axis(maybe_callable, axis=axis)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexing.py:1432, in _LocIndexer._getitem_axis(self, key, axis)
#    1430 # fall thru to straight lookup
#    1431 self._validate_key(key, axis)
# -> 1432 return self._get_label(key, axis=axis)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexing.py:1382, in _LocIndexer._get_label(self, label, axis)
#    1380 def _get_label(self, label, axis: AxisInt):
#    1381     # GH#5567 this will fail if the label is not present in the axis.
# -> 1382     return self.obj.xs(label, axis=axis)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\generic.py:4323, in NDFrame.xs(self, key, axis, level, drop_level)
#    4321             new_index = index[loc]
#    4322 else:
# -> 4323     loc = index.get_loc(key)
#    4325     if isinstance(loc, np.ndarray):
#    4326         if loc.dtype == np.bool_:
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\range.py:417, in RangeIndex.get_loc(self, key)
#     415         raise KeyError(key) from err
#     416 if isinstance(key, Hashable):
# --> 417     raise KeyError(key)
#     418 self._check_indexing_error(key)
#     419 raise KeyError(key)
#
# KeyError: 'E103'
