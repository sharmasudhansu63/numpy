# %%
import numpy as np
import pandas as pd

# %%
import pandas as pd
df = pd.read_csv("student_performance.csv")
df
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group C                some college  free/reduced
# 1    female        group E            some high school  free/reduced
# 2    female        group E            some high school      standard
# 3      male        group C             master's degree  free/reduced
# 4      male        group C          associate's degree  free/reduced
# ..      ...            ...                         ...           ...
# 995    male        group B           bachelor's degree      standard
# 996    male        group D                 high school      standard
# 997    male        group D                some college  free/reduced
# 998    male        group A            some high school      standard
# 999    male        group A          associate's degree      standard
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
df.head(5)
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group C                some college  free/reduced
# 1  female        group E            some high school  free/reduced
# 2  female        group E            some high school      standard
# 3    male        group C             master's degree  free/reduced
# 4    male        group C          associate's degree  free/reduced
#
#   test preparation course  math score  reading score  writing score  \
# 0               completed        69.0           73.0           49.0
# 1                    none        61.0           47.0           99.0
# 2                    none        76.0           62.0          100.0
# 3                    none        30.0           95.0           94.0
# 4                    none        56.0           99.0           54.0
#
#    total_score   avg score
# 0        191.0  187.300403
# 1        207.0  187.300403
# 2        238.0  187.300403
# 3        219.0  187.300403
# ...

# %%
df.shape
# Out:
# (1000, 8)

# %%
df.tail(5)
# Out:
#     gender race/ethnicity parental level of education         lunch  \
# 995   male        group B           bachelor's degree      standard
# 996   male        group D                 high school      standard
# 997   male        group D                some college  free/reduced
# 998   male        group A            some high school      standard
# 999   male        group A          associate's degree      standard
#
#     test preparation course  math score  reading score  writing score  \
# 995               completed        59.0           84.0           75.0
# 996               completed        78.0           62.0           66.0
# 997               completed        32.0           94.0           47.0
# 998                    none        42.0           64.0           62.0
# 999                    none        31.0           60.0           79.0
#
#      total_score   avg score
# 995        218.0  187.300403
# 996        206.0  187.300403
# 997        173.0  187.300403
# ...

# %%
df.columns
# Out:
# Index(['gender', 'race/ethnicity', 'parental level of education', 'lunch',
#        'test preparation course', 'math score', 'reading score',
#        'writing score', 'total_score', 'avg score'],
#       dtype='object')

# %%
df.dtypes
# Out:
# gender                          object
# race/ethnicity                  object
# parental level of education     object
# lunch                           object
# test preparation course         object
# math score                     float64
# reading score                  float64
# writing score                  float64
# dtype: object

# %%
df.isnull().sum()
# Out:
# gender                         3
# race/ethnicity                 3
# parental level of education    4
# lunch                          2
# test preparation course        3
# math score                     2
# reading score                  3
# writing score                  3
# dtype: int64

# %%
df[["math score","reading score"]]
# Out:
#      math score  reading score
# 0          69.0           73.0
# 1          61.0           47.0
# 2          76.0           62.0
# 3          30.0           95.0
# 4          56.0           99.0
# ..          ...            ...
# 995        59.0           84.0
# 996        78.0           62.0
# 997        32.0           94.0
# 998        42.0           64.0
# 999        31.0           60.0
#
# [1000 rows x 2 columns]

# %%
print(df["gender"].value_counts())
# Out:
# gender
# male      506
# female    491
# Name: count, dtype: int64

# %%
print(df["lunch"].unique())
# Out:
# ['free/reduced' 'standard' nan]

# %%
(df[df["math score"] > 80])
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 11     male        group E           bachelor's degree      standard
# 13   female        group D                some college  free/reduced
# 15   female        group C          associate's degree      standard
# 18     male        group C                some college      standard
# 21     male        group A          associate's degree  free/reduced
# ..      ...            ...                         ...           ...
# 969  female        group D                some college      standard
# 972    male        group D            some high school  free/reduced
# 973    male        group E             master's degree  free/reduced
# 977  female        group A            some high school      standard
# 979  female        group B                some college      standard
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
print(df["test preparation course"].unique())
# Out:
# ['completed' 'none' nan]

# %%
print(df[df["test preparation course"]=='completed'])
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group C                some college  free/reduced
# 6    female        group E          associate's degree  free/reduced
# 7      male        group D          associate's degree  free/reduced
# 10   female        group C                 high school  free/reduced
# 11     male        group E           bachelor's degree      standard
# ..      ...            ...                         ...           ...
# 992    male        group E             master's degree      standard
# 994    male        group D             master's degree      standard
# 995    male        group B           bachelor's degree      standard
# 996    male        group D                 high school      standard
# 997    male        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
print(df[(df["gender"] == "female") & (df["reading score"] > 80) ])
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 10   female        group C                 high school  free/reduced
# 13   female        group D                some college  free/reduced
# 30   female        group C           bachelor's degree      standard
# 48   female        group C            some high school  free/reduced
# 59   female        group A           bachelor's degree      standard
# ..      ...            ...                         ...           ...
# 960  female        group C            some high school      standard
# 967  female        group B                 high school      standard
# 974  female        group C                 high school      standard
# 983  female        group B                 high school      standard
# 990  female        group C            some high school  free/reduced
#
#     test preparation course  math score  reading score  writing score  \
# ...

# %%
print(df.groupby("gender")["reading score"].mean())
# Out:
# gender
# female    63.353783
# male      62.413861
# Name: reading score, dtype: float64

# %%
print(df.groupby("race/ethnicity").size())
# Out:
# race/ethnicity
# group A    212
# group B    199
# group C    206
# group D    169
# group E    211
# dtype: int64

# %%
print(df.groupby("gender")["reading score"].mean())
# Out:
# gender
# female    63.353783
# male      62.413861
# Name: reading score, dtype: float64

# %%
print(df.sort_values("math score",ascending = False).head(10))
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 801  female        group A            some high school      standard
# 126    male        group B          associate's degree  free/reduced
# 433    male        group E          associate's degree  free/reduced
# 878    male        group A                 high school  free/reduced
# 827    male        group E             master's degree      standard
# 642  female        group A          associate's degree      standard
# 283  female        group C            some high school  free/reduced
# 495  female        group A           bachelor's degree      standard
# 130    male        group B            some high school      standard
# 915    male        group A                 high school      standard
#
#     test preparation course  math score  reading score  writing score
# 801               completed       100.0           29.0           69.0
# ...

# %%
df["total_score"]=df["math score"]+df["reading score"]+df["writing score"]

# %%
df
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group C                some college  free/reduced
# 1    female        group E            some high school  free/reduced
# 2    female        group E            some high school      standard
# 3      male        group C             master's degree  free/reduced
# 4      male        group C          associate's degree  free/reduced
# ..      ...            ...                         ...           ...
# 995    male        group B           bachelor's degree      standard
# 996    male        group D                 high school      standard
# 997    male        group D                some college  free/reduced
# 998    male        group A            some high school      standard
# 999    male        group A          associate's degree      standard
#
#     test preparation course  math score  reading score  writing score  \
# ...

# %%
df["avg score"] = df["total_score"].mean()
df
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group C                some college  free/reduced
# 1    female        group E            some high school  free/reduced
# 2    female        group E            some high school      standard
# 3      male        group C             master's degree  free/reduced
# 4      male        group C          associate's degree  free/reduced
# ..      ...            ...                         ...           ...
# 995    male        group B           bachelor's degree      standard
# 996    male        group D                 high school      standard
# 997    male        group D                some college  free/reduced
# 998    male        group A            some high school      standard
# 999    male        group A          associate's degree      standard
#
#     test preparation course  math score  reading score  writing score  \
# ...
